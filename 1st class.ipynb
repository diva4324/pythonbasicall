# %%
print("PARU")
# Out:
# PARU

# %%
### About jupyter notebook

# %%
###comments
# single line
''' multi-line comment '''
"""multi-line   comment """

# %%
""The rain paused without w

arning, leaving the streets shining like freshly polished mirrors. A stray cat sat near a closed shop, watching reflections ripple in puddles as distant traffic hummed. Somewhere above, clouds drifted lazily, undecided about their next move, while the city quietly resumed its rhythm.""

# %%
y='5'
type(y)
# Out:
# str

# %%
x=5
type(x)
# Out:
# int

# %%
z=5

# %%
a=x+z
print(a)
# Out:
# 10

# %%
b='6'
c=y+b
print(c)
# Out:
# 56

# %%
b=int(b)
y=int(y)
d=b+y
print(d)
# Out:
# 11

# %%
e=str(d)
type(e)
# Out:
# str

# %%
age= input("enter the age:")
type(age)
# Out:
# enter the age: 5
# str

# %%
age= int(input("enter the age:"))
# Out:
# enter the age: 5

# %%
type(age)
# Out:
# int

# %%
var = 6
float1 = 3.5
result=var + float1
print(result)
# Out:
# 9.5

# %%
name= "Paru"
surname="tiwari"
age= 21

# %%
#fstring
print(f"My name is {name} and surname {surname}")
#sajilo ko lai so that " ra , use garna naparos

print("My name is", name,"and surname", surname)
# Out:
# My name is Paru and surname tiwari
# My name is Paru and surname tiwari

# %%
# dot format

print("My name is {} {}".format(name, surname))
print("My name is {} {}".format("Suraj", "Sharma"))
# Out:
# My name is Paru tiwari
# My name is Suraj Sharma

# %%
a = "50"
z = 1j

b = 3.5
is_student = True

type(a)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
type(b)
# Out:
# float

# %%
type(is_student)
# Out:
# bool

# %%
a = "55"
b = "3"

c = a + b
print(c)
# Out:
# 553

# %%
name= input("enter your name")
# Out:
# enter your name pragya

# %%
no = int(input("enter your class no"))
# Out:
# enter your class no 23

# %%
type(no)
# Out:
# int

# %%
## Assign multi value
a, b = 3, 4

# %%
a, b = 3, 4
temp = 3
b = temp
b = a
#yesto temp aru ma garna parthiyo tara python ma direct a,b=b,a garna milcha

# %%
 a, b = b, a

# %%
b
# Out:
# 3

# %%
result=5>9
result
# Out:
# False

# %%
type(result)
# Out:
# bool
