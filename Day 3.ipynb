# %%
a=20
b=3

# %%
print(f"Addition (a + b): {a+b}")
# Out:
# Addition (a + b): 23

# %%
print(f"subtraction: {a-b}")

]
# Out:
# subtraction: 17

# %%
print(f"multiplication (a * b): {a*b}")
# Out:
# multiplication (a * b): 60

# %%
print(f"division (a / b): {a/b}")
# Out:
# division (a / b): 6.666666666666667

# %%
print(f"floordivison (a // b): {a//b}")
# Out:
# floordivison (a // b): 6

# %%
print(f"modulos (a % b): {a%b}")
# Out:
# modulos (a % b): 2

# %%
print(f"Exponentiation (a ** b): {a ** b}")
# Out:
# Exponentiation (a ** b): 8000

# %%
print(f"Division (10 / 3): {10 / 3}")           # Division (returns float)
print(f"Floor Division (10 // 3): {10 // 3}")
# Out:
# Division (10 / 3): 3.3333333333333335
# Floor Division (10 // 3): 3

# %%
# Comparison operators
x = 10
y = 5

print(f"x = {x}, y = {y}")
print(f"Equal to (x == y): {x == y}")
print(f"Not equal to (x != y): {x != y}")
# Out:
# x = 10, y = 5
# Equal to (x == y): False
# Not equal to (x != y): True

# %%
print(f"greater than (x > y): {x> y}")
# Out:
# greater than (x > y): True

# %%
print(f"less than (x < y): {x< y}")
# Out:
# less than (x < y): False

# %%
print(f"greater than or equal to (x >= y): {x>= y}")
# Out:
# greater than or equal to (x >= y): True

# %%
print(f"less than or equal to (x <= y): {x<= y}")
# Out:
# less than or equal to (x <= y): False

# %%
# Practical examples
age = 25
voting_age = 18
speed = 75
speed_limit = 65
password = "python123"
entered_password = "python1123"

# %%
print(f"for voting (age >= voting_age): {age>= voting_age}")
# Out:
# for voting (age >= voting_age): True

# %%
speed1 = int(input("enter your speed:"))
# Out:
# enter your speed: 80

# %%
print(f" speed exceed? : {speed1>speed_limit}")
# Out:
#  speed exceed? : True

# %%
# Comparing different data types
print(f"\n10 == 10.0: {10 == 10.0}")  
print(f"'hello' == 'Hello': {'hello' == 'Hello'}")
# Out:
# 10 == 10.0: True
# 'hello' == 'Hello': False

# %%
result = (10 + 5) * 2 > 25
print(f"(10 + 5) * 2 > 25: {result}")
# Out:
# (10 + 5) * 2 > 25: True

# %% [raw]
# # syntax
#
# if :
#
# elif:
#
# else:

# %%
age= int(input("enter the age"))
print(f"Age is: {age}")

if age >=18:
    print("you are adult")

print("program finished")
# Out:
# enter the age 16
# Age is: 16
# program finished

# %%
age1= int(input("enter the age"))
print(f"Age is: {age1}")

if age1>=18:
    print("you are adult")
    

    
else:
    print("you are child")
# Out:
# enter the age 78
# Age is: 78
# you are adult

# %%
print("-" *20)
# Out:
# --------------------

# %%
print("pragya " *20)
# Out:
# pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya pragya

# %%
# Example 3:
score = float(input("enter the score"))
print(f"Score is: {score}")

if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
elif score >= 70:
    print("Grade: C")
elif score >= 60:
    print("Grade: D")
else:
    print("Grade: F")

print("-" * 20)
# Out:
# enter the score 88.8
# Score is: 88.8
# Grade: B
# --------------------

# %% [raw]
# #Conditions with logical operators (and, or, not)
# #AND
# | True | True | T |
# | True | False | F |
# | False | True | F |
# | False | False | F |
#
# #OR
# | True | True | T |
# | True | False | T |
# | False | True | T |
# | False | False | F |
#
# #NOT
# | True | False |
# | False | True |

# %%
# Example 4: Conditions with logical operators (and, or, not)
has_ticket = True
has_id = True
print(f"Has Ticket: {has_ticket}, Has ID: {has_id}")
if has_ticket and has_id:
    print("Entry allowed:")
elif has_ticket or has_id:
    print("partial requirement. check with staff")
    if not has_id:
        print("waening :id is missing!")
else:
    print("entry denied")
# Out:
# Has Ticket: True, Has ID: True
# Entry allowed:

# %%
summing_dress= False
has_ticket=False
can_swim=False
if has_ticket and can_swim and summing_dress :
    print("Entry allowed:")
elif has_ticket or summing_dress and can_swim:
    print("partially allowed:")
    if not summing_dress:
        print("you can buy swimming dress from our shop!")
    if not has_ticket:
        print("bring ticket")
else:
    print("entry denied")
# Out:
# entry denied
