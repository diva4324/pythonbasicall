# %% [markdown]
# ### Introduction to FastAPI
# * FastAPI is a modern, fast (high-performance), web framework for building APIs with Python 3.6+ based on standard Python type hints.
# * Key Features:
# * Fast: Very high performance (Pydantic).
# * Fast to code: Increase the speed to develop features by about 200% to 300%.
# * Automatic Docs: It automatically generates interactive API documentation (Swagger UI).
# * Let's start by installing the necessary libraries.

# %% [markdown]
# ### Running FastAPI in Jupyter
# * Normally, you run FastAPI from the command line (terminal) using
# #### uvicorn main:app --reload

# %%
import uvicorn
from fastapi import FastAPI

# %% [markdown]
# ### Dependency Injection
# * This is one of FastAPI's most powerful features.
# * It allows you to share logic (like database connections, authentication, or pagination) across multiple path operations.
# * We use the Depends class.
